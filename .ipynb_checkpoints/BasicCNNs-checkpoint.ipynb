# %%
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.keras.datasets.mnist import load_data
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data
#
# We will test each model on MNIST classification.

# %%
data = load_data()

# %%
X_train = data[0][0]
y_train = data[0][1]
X_test = data[1][0]
y_test = data[1][1]

# %%
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)

# %%
def one_hot(y, n):
    temp = np.zeros((len(y), n))
    for i in range(len(y)):
        temp[i, y[i]] = 1
    return temp

y_train = one_hot(y_train, 10)
y_test = one_hot(y_test, 10)

# %% [markdown]
# # Models

# %%
def first_n(model, X, y, n):
    n = np.sqrt(n)
    if int(n)!=n:
        raise ValueError("Invalid n. Must be a perfect square.")
    else:
        n = int(n)
        fig, ax = plt.subplots(n,n, figsize = (10*n/3,10*n/3))
        for i in range(n):
            for j in range(n):
                targ = np.argmax(y[n*i+j])
                img = X[n*i+j]
                pred = np.argmax(model.predict(np.expand_dims(img, axis = 0)))
                ax[i][j].imshow(img)
                ax[i][j].set_title(f"Target = {targ}, Prediction = {pred}")
                ax[i][j].get_xaxis().set_ticklabels([])
                ax[i][j].get_yaxis().set_ticklabels([])

# %% [markdown]
# ## LeNet5:

# %%
def LeNet5(input_shape):
    in_img = tf.keras.Input(shape = input_shape)
    out = tfl.Conv2D(kernel_size = 5, filters = 6, padding = "valid", activation = "sigmoid")(in_img)
    out = tfl.AvgPool2D(pool_size = 2, strides = 2)(out)
    out = tfl.Conv2D(kernel_size = 5, filters = 16, padding = "valid", activation = "sigmoid")(out)
    out = tfl.AvgPool2D(pool_size = 2, strides = 2)(out)
    out = tfl.Flatten()(out)
    out = tfl.Dense(input_shape = out.shape, units = 120, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 84, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 10, activation = "softmax")(out)
    model = tf.keras.Model(inputs=in_img, outputs=out)
    return model

# %%
LeNet5_model = LeNet5((X_train[0].shape))
LeNet5_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 24, 24, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               30840
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet5_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
histories = []
history = LeNet5_model.fit(X_train, y_train, epochs = 10, validation_data = (X_test, y_test))
histories.append(history)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 20s 10ms/step - loss: 1.1144 - accuracy: 0.6447 - val_loss: 0.1841 - val_accuracy: 0.9430
# Epoch 2/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1576 - accuracy: 0.9534 - val_loss: 0.0943 - val_accuracy: 0.9704
# Epoch 3/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0997 - accuracy: 0.9691 - val_loss: 0.0736 - val_accuracy: 0.9773
# Epoch 4/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0757 - accuracy: 0.9762 - val_loss: 0.0591 - val_accuracy: 0.9818
# Epoch 5/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0647 - accuracy: 0.9800 - val_loss: 0.0523 - val_accuracy: 0.9829
# Epoch 6/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0543 - accuracy: 0.9829 - val_loss: 0.0588 - val_accuracy: 0.9816
# Epoch 7/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.0511 - val_accuracy: 0.9837
# Epoch 8/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.0503 - val_accuracy: 0.9820
# Epoch 9/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0401 - accuracy: 0.9871 - val_loss: 0.0401 - val_accuracy: 0.9882
# Epoch 10/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0345 - accuracy: 0.9896 - val_loss: 0.0359 - val_accuracy: 0.9887

# %%
first_n(LeNet5_model, X_test, y_test, 16)

# %% [markdown]
# ## ResNet
#
# We will go for a ResNet with three residual blocks and pooling after the shortcut connections.

# %%
def residual_block(in_img, conv_size, pool_size, conv_stride, pool_stride, n_filters):
    out1 = tfl.Conv2D(kernel_size = conv_size, filters = n_filters, strides = conv_stride, padding = "same", activation = "relu")(in_img)
    out2 = tfl.Conv2D(kernel_size = conv_size, filters = n_filters, strides = conv_stride, padding = "same")(out1)
    out = tfl.ReLU()(out2+out1)
    out = tfl.MaxPool2D(pool_size = pool_size, strides = pool_stride)(out)
    return out

# %%
def ResNet(input_shape):
    in_img = tf.keras.Input(shape = input_shape)
    out = residual_block(in_img, 3, 2, 1, 2, 8)
    out = residual_block(out, 3, 2, 1, 2, 16)
    out = tfl.Flatten()(out)
    out = tfl.Dense(input_shape = out.shape, units = 120, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 84, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 10, activation = "softmax")(out)
    model = tf.keras.Model(inputs=in_img, outputs=out)
    return model

# %%
ResNet_model = ResNet((X_train[0].shape))
ResNet_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 8)    80          input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 8)    584         conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 28, 28, 8)    0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 28, 28, 8)    0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 14, 14, 8)    0           re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 16)   1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 16)   2320        conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 14, 14, 16)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 14, 14, 16)   0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 16)     0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 784)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 120)          94200       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 84)           10164       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           850         dense_4[0][0]
# ==================================================================================================
# Total params: 109,366
# Trainable params: 109,366
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
ResNet_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
history = ResNet_model.fit(X_train, y_train, epochs = 10, validation_data = (X_test, y_test))
histories.append(history)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 46s 24ms/step - loss: 1.0074 - accuracy: 0.7316 - val_loss: 0.1040 - val_accuracy: 0.9723
# Epoch 2/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.1277 - accuracy: 0.9623 - val_loss: 0.1061 - val_accuracy: 0.9678
# Epoch 3/10
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.1154 - accuracy: 0.9654 - val_loss: 0.1313 - val_accuracy: 0.9599
# Epoch 4/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.1070 - accuracy: 0.9668 - val_loss: 0.0861 - val_accuracy: 0.9730
# Epoch 5/10
# 1875/1875 [==============================] - 46s 25ms/step - loss: 0.0917 - accuracy: 0.9730 - val_loss: 0.0898 - val_accuracy: 0.9727
# Epoch 6/10
# 1875/1875 [==============================] - 46s 25ms/step - loss: 0.0943 - accuracy: 0.9706 - val_loss: 0.0844 - val_accuracy: 0.9727
# Epoch 7/10
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.0971 - accuracy: 0.9709 - val_loss: 0.1547 - val_accuracy: 0.9500
# Epoch 8/10
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.1050 - accuracy: 0.9669 - val_loss: 0.1281 - val_accuracy: 0.9604
# Epoch 9/10
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.1266 - accuracy: 0.9608 - val_loss: 0.1091 - val_accuracy: 0.9677
# Epoch 10/10
# 1875/1875 [==============================] - 46s 25ms/step - loss: 0.1230 - accuracy: 0.9622 - val_loss: 0.2333 - val_accuracy: 0.9254

# %%
first_n(ResNet_model, X_test, y_test, 16)

# %% [markdown]
# ## Inception Network

# %%
def inception_block(in_img, n_filters, start1d = None):
    if start1d:
        in_img = tfl.Conv2D(kernel_size = 1, filters = start1d, strides = 1, padding = "same", activation = "relu")(in_img)
    out1 = tfl.Conv2D(kernel_size = 1, filters = n_filters[0], strides = 1, padding = "same", activation = "relu")(in_img)
    out2 = tfl.Conv2D(kernel_size = 3, filters = n_filters[1], strides = 1, padding = "same", activation = "relu")(in_img)
    out3 = tfl.Conv2D(kernel_size = 5, filters = n_filters[2], strides = 1, padding = "same", activation = "relu")(in_img)
    out4 = tfl.MaxPool2D(pool_size = 2, strides = 1,padding = "same")(in_img)
    out = tf.keras.layers.Concatenate(axis=3)([out1,out2,out3,out4])
    out = tfl.MaxPool2D(pool_size = 2, strides = 2)(out)
    return out

# %%
def InceptionNet(input_shape):
    in_img = tf.keras.Input(shape = input_shape)
    out = inception_block(in_img, [32, 64, 16])
    out = inception_block(out, [32, 64, 16], start1d = 8)
    out = tfl.Flatten()(out)
    out = tfl.Dense(input_shape = out.shape, units = 120, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 84, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 10, activation = "softmax")(out)
    model = tf.keras.Model(inputs=in_img, outputs=out)
    return model

# %%
InceptionNet_model = InceptionNet((X_train[0].shape))
InceptionNet_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 32)   64          input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 64)   640         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 16)   416         input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 1)    0           input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 113)  0           conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 113)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 8)    912         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 32)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 64)   4672        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 16)   3216        conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 8)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 120)  0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 120)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 5880)         0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 120)          705720      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 84)           10164       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           850         dense_7[0][0]
# ==================================================================================================
# Total params: 726,942
# Trainable params: 726,942
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
InceptionNet_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
history = InceptionNet_model.fit(X_train, y_train, epochs = 10, validation_data = (X_test, y_test))
histories.append(history)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 116s 61ms/step - loss: 0.7954 - accuracy: 0.8317 - val_loss: 0.1611 - val_accuracy: 0.9545
# Epoch 2/10
# 1875/1875 [==============================] - 114s 61ms/step - loss: 0.1849 - accuracy: 0.9462 - val_loss: 0.1350 - val_accuracy: 0.9589
# Epoch 3/10
# 1875/1875 [==============================] - 116s 62ms/step - loss: 0.1782 - accuracy: 0.9461 - val_loss: 0.1637 - val_accuracy: 0.9484
# Epoch 4/10
# 1875/1875 [==============================] - 116s 62ms/step - loss: 0.1691 - accuracy: 0.9483 - val_loss: 0.2351 - val_accuracy: 0.9265
# Epoch 5/10
# 1875/1875 [==============================] - 115s 61ms/step - loss: 0.2040 - accuracy: 0.9357 - val_loss: 0.1889 - val_accuracy: 0.9410
# Epoch 6/10
# 1875/1875 [==============================] - 116s 62ms/step - loss: 0.2222 - accuracy: 0.9308 - val_loss: 0.1970 - val_accuracy: 0.9379
# Epoch 7/10
# 1875/1875 [==============================] - 114s 61ms/step - loss: 0.1891 - accuracy: 0.9429 - val_loss: 0.1592 - val_accuracy: 0.9487
# Epoch 8/10
# 1875/1875 [==============================] - 115s 61ms/step - loss: 0.1710 - accuracy: 0.9472 - val_loss: 0.1730 - val_accuracy: 0.9460
# Epoch 9/10
# 1875/1875 [==============================] - 114s 61ms/step - loss: 0.1663 - accuracy: 0.9486 - val_loss: 0.1729 - val_accuracy: 0.9447
# Epoch 10/10
# 1875/1875 [==============================] - 116s 62ms/step - loss: 0.1886 - accuracy: 0.9414 - val_loss: 0.1458 - val_accuracy: 0.9575

# %%
first_n(InceptionNet_model, X_test, y_test, 16)

# %% [markdown]
# ## MobileNet

# %%
def DepthwiseSeparableConv2D(in_img, n_filters, kernel_size, stride, padding):
    depthwise = []
    for i in range(in_img.shape[3]):
        expand_layer = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x[:,:,:,i], axis = 3))
        img = expand_layer(in_img)
        depthwise.append(tfl.Conv2D(kernel_size = kernel_size, filters = 1, strides = stride, padding = padding)(img))
    if len(depthwise)>1:
        out = tf.keras.layers.Concatenate(axis=3)(depthwise)
    else:
        out = depthwise[0]
    out = tfl.Conv2D(kernel_size = 1, filters = n_filters, strides = 1, padding = "same", activation = "sigmoid")(out)
    return out

# %%
def MobileNet(input_shape):
    in_img = tf.keras.Input(shape = input_shape)
    out = DepthwiseSeparableConv2D(in_img, 6, 5, stride = 1, padding = "valid")
    out = tfl.MaxPool2D(pool_size = 2, strides = 2)(out)
    out = DepthwiseSeparableConv2D(out, 16, 5, stride = 1, padding = "valid")
    out = tfl.MaxPool2D(pool_size = 2, strides = 2)(out)
    out = tfl.Flatten()(out)
    out = tfl.Dense(input_shape = out.shape, units = 120, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 84, activation = "sigmoid")(out)
    out = tfl.Dense(input_shape = out.shape, units = 10, activation = "softmax")(out)
    model = tf.keras.Model(inputs=in_img, outputs=out)
    return model

# %%
MobileNet_model = MobileNet((X_train[0].shape))
MobileNet_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 28, 28, 1)    0           input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 24, 24, 1)    26          lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 24, 24, 6)    12          conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 6)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 12, 12, 1)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 12, 12, 1)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 12, 12, 1)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 12, 12, 1)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 12, 12, 1)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 12, 12, 1)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 1)      26          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 1)      26          lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 1)      26          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 1)      26          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 1)      26          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 1)      26          lambda_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 6)      0           conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 16)     112         concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 4, 4, 16)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 256)          0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 120)          30840       flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 84)           10164       dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 10)           850         dense_10[0][0]
# ==================================================================================================
# Total params: 42,160
# Trainable params: 42,160
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
MobileNet_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
history = MobileNet_model.fit(X_train, y_train, epochs = 10, validation_data = (X_test, y_test))
histories.append(history)

# Look into time not being quicker than LeNet
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 28s 14ms/step - loss: 1.6708 - accuracy: 0.4016 - val_loss: 0.4734 - val_accuracy: 0.8508
# Epoch 2/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4371 - accuracy: 0.8603 - val_loss: 0.2620 - val_accuracy: 0.9193
# Epoch 3/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2494 - accuracy: 0.9217 - val_loss: 0.2047 - val_accuracy: 0.9358
# Epoch 4/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1744 - accuracy: 0.9448 - val_loss: 0.1273 - val_accuracy: 0.9588
# Epoch 5/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1380 - accuracy: 0.9572 - val_loss: 0.1126 - val_accuracy: 0.9627
# Epoch 6/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1147 - accuracy: 0.9643 - val_loss: 0.0944 - val_accuracy: 0.9702
# Epoch 7/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0983 - accuracy: 0.9682 - val_loss: 0.0956 - val_accuracy: 0.9684
# Epoch 8/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0832 - accuracy: 0.9733 - val_loss: 0.0797 - val_accuracy: 0.9748
# Epoch 9/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0728 - accuracy: 0.9767 - val_loss: 0.0807 - val_accuracy: 0.9759
# Epoch 10/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0675 - accuracy: 0.9783 - val_loss: 0.0725 - val_accuracy: 0.9781

# %%
first_n(MobileNet_model, X_test, y_test, 16)

# %% [markdown]
# # Comparison

# %%
histories = [pd.DataFrame(h.history) for h in histories]

# %%
models = ["LeNet", "ResNet", "InceptionNet", "MobileNet"]

# %%
fig, ax = plt.subplots(2,2, figsize = (15,10))
for i in range(2):
    for j in range(2):
        ax[i][j].plot(histories[2*i+j].accuracy.values, "k-", label = "train acc")
        ax[i][j].plot(histories[2*i+j].val_accuracy.values, "r-", label = "val acc")
        ax[i][j].set_title(models[2*i+j])
        ax[i][j].set_xlabel("epochs")
        ax[i][j].legend()

# %%
fig, ax = plt.subplots(1,1, figsize = (15,10))
for i in range(4):
    ax.plot(histories[i].val_accuracy.values, label = f"{models[i]} val acc")
ax.set_xlabel("epochs")
ax.legend()
ax.set_title("Validation Accuracy Across Models")
# Out:
# Text(0.5, 1.0, 'Validation Accuracy Across Models')
